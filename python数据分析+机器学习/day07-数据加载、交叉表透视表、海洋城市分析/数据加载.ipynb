# %% [markdown]
# ### pandas提供了一些用于将表格型数据读取为DataFrame对象的函数，期中read_csv和read_table这两个使用最多

# %% [markdown]
# 首先查看文本文件

# %% [markdown]
# - 使用read_csv将其读入
#
# - 使用read_table读取

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
data = pd.read_csv('data/type-.txt',sep='-',header=None)
data.columns = ['汇源','果汁','鸟']
data
# Out:
#    汇源  果汁    鸟
# 0  你好  我好  他也好
# 1  也许  大概  有可能
# 2  然而  未必  不见得

# %%
table = pd.read_table('data/type_comma',sep=',',header=None)
table
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12   python

# %% [markdown]
# 使用read_excel()读取excel表格

# %%
table = pd.read_excel('data/students.xlsx',sheet_name=1)
table
# Out:
#     name  age    address
# 0  daner   19    beijing
# 1   mery   20   shanghai
# 2   lucy   20  guangzhou

# %% [markdown]
# 写入excel文件

# %%
table.to_excel('dancer.xlsx')

# %% [markdown]
# 读取sqlite文件

# %% [markdown]
# 导包  import sqlite3 as sqlite3

# %% [markdown]
# - 连接数据库
#     sqlite3.connect('dbpath')
#
# - 读取table内容
#     pd.read_sql("SQL语句", con)
#
# - 写入数据库文件
#     df对象.to_sql('dbpath',connection)
#
# - 操作数据库
#     connection.execute(SQL语句)

# %%
import sqlite3 as sqlite3

# %%
# SQL server  MongoDB  Redis

# %%
connection = sqlite3.connect('data/weather_2012.sqlite')

# %%
pd.read_sql('select * from weather_2012',connection)
# Out:
#       index            Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0         0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1         1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2         2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3         3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4         4  2012-01-01 04:00:00      -1.5                -3.3           88
# 5         5  2012-01-01 05:00:00      -1.4                -3.3           87
# 6         6  2012-01-01 06:00:00      -1.5                -3.1           89
# 7         7  2012-01-01 07:00:00      -1.4                -3.6           85
# 8         8  2012-01-01 08:00:00      -1.4                -3.6           85
# 9         9  2012-01-01 09:00:00      -1.3                -3.1           88
# 10       10  2012-01-01 10:00:00      -1.0                -2.3           91
# 11       11  2012-01-01 11:00:00      -0.5                -2.1           89
# 12       12  2012-01-01 12:00:00      -0.2                -2.0           88
# 13       13  2012-01-01 13:00:00       0.2                -1.7           87
# 14       14  2012-01-01 14:00:00       0.8                -1.1           87
# 15       15  2012-01-01 15:00:00       1.8                -0.4           85
# 16       16  2012-01-01 16:00:00       2.6                -0.2           82
# 17       17  2012-01-01 17:00:00       3.0                 0.0           81
# 18       18  2012-01-01 18:00:00       3.8                 1.0           82
# 19       19  2012-01-01 19:00:00       3.1                 1.3           88
# 20       20  2012-01-01 20:00:00       3.2                 1.3           87
# 21       21  2012-01-01 21:00:00       4.0                 1.7           85
# 22       22  2012-01-01 22:00:00       4.4                 1.9           84
# 23       23  2012-01-01 23:00:00       5.3                 2.0           79
# 24       24  2012-01-02 00:00:00       5.2                 1.5           77
# 25       25  2012-01-02 01:00:00       4.6                 0.0           72
# 26       26  2012-01-02 02:00:00       3.9                -0.9           71
# 27       27  2012-01-02 03:00:00       3.7                -1.5           69
# 28       28  2012-01-02 04:00:00       2.9                -2.3           69
# 29       29  2012-01-02 05:00:00       2.6                -2.3           70
# ...               ...              ...              ...                   ...
# 8754               24             25.0           101.36          Mainly Clear
# 8755               26             25.0           101.47          Mainly Clear
# 8756               24             25.0           101.52                 Clear
# 8757               20             25.0           101.50          Mainly Clear
# 8758               19             25.0           101.54          Mainly Clear
# 8759               28             25.0           101.52         Mostly Cloudy
# 8760               26             25.0           101.51                Cloudy
# 8761               15             25.0           101.50                Cloudy
# 8762                9             25.0           101.45                Cloudy
# 8763                6             25.0           101.42         Mostly Cloudy
# 8764               11             25.0           101.34                Cloudy
# 8765                6             25.0           101.28                Cloudy
# 8766                4             25.0           101.23                Cloudy
# 8767                0             19.3           101.19          Snow Showers
# 8768                4              3.2           101.14          Snow Showers
# 8769                4              2.4           101.09                  Snow
# 8770                4              6.4           101.05              Snow,Fog
# 8771                9              9.7           100.93                  Snow
# 8772                4             12.9           100.78                  Snow
# 8773                4             12.9           100.63                  Snow
# 8774                6             11.3           100.57                  Snow
# 8775                9              9.7           100.47                  Snow
# 8776               13             12.9           100.40                  Snow
# 8777               19              9.7           100.30                  Snow
# 8778               17              9.7           100.19                  Snow
# 8779               30              9.7           100.13                  Snow
# 8780               24              9.7           100.03                  Snow
# 8781               28              4.8            99.95                  Snow
# 8782               28              9.7            99.91                  Snow
# 8783               30             11.3            99.89                  Snow
#
# [8784 rows x 9 columns]

# %%
table.to_sql('dancer',connection)

# %%
pd.read_sql('select * from dancer',connection)
# Out:
#    index   name  age    address
# 0      0  daner   19    beijing
# 1      1   mery   20   shanghai
# 2      2   lucy   20  guangzhou

# %%
# drop table dancer
connection.execute('drop table dancer')

# %%
pd.read_sql('select * from dancer',connection)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# d:\python3.6\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1408             else:
# -> 1409                 cur.execute(*args)
#    1410             return cur
#
# OperationalError: no such table: dancer
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-69-b368fec0516f> in <module>()
# ----> 1 pd.read_sql('select * from dancer',connection)
#
# d:\python3.6\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     398             sql, index_col=index_col, params=params,
#     399             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 400             chunksize=chunksize)
#     401
#     402     try:
#
# d:\python3.6\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1442
#    1443         args = _convert_params(sql, params)
# -> 1444         cursor = self.execute(*args)
#    1445         columns = [col_desc[0] for col_desc in cursor.description]
#    1446
#
# d:\python3.6\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1419             ex = DatabaseError(
#    1420                 "Execution failed on sql '%s': %s" % (args[0], exc))
# -> 1421             raise_with_traceback(ex)
#    1422
#    1423     @staticmethod
#
# d:\python3.6\lib\site-packages\pandas\compat\__init__.py in raise_with_traceback(exc, traceback)
#     365         if traceback == Ellipsis:
#     366             _, _, traceback = sys.exc_info()
# --> 367         raise exc.with_traceback(traceback)
#     368 else:
#     369     # this version of raise is a syntax error in Python 3
#
# d:\python3.6\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1407                 cur.execute(*args, **kwargs)
#    1408             else:
# -> 1409                 cur.execute(*args)
#    1410             return cur
#    1411         except Exception as exc:
#
# DatabaseError: Execution failed on sql 'select * from dancer': no such table: dancer

# %% [markdown]
# 设置行索引index_col

# %% [markdown]
# 写入sql文件

# %% [markdown]
# 使用read_csv读取url获取网络上的数据
# url = 'https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv'

# %%
url = 'https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.cs